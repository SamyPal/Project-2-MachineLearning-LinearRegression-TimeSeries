# %% [markdown]
# # Web Scraping: Selenium
# _Automate your browser._ <br>
# _Collect data from dynamically generated web pages or those requiring user interaction._
#
# ### Docs
#
# - [Selenium homepage](https://www.seleniumhq.org/)
# - [Selenium documentation](https://selenium-python.readthedocs.io/) - unofficial, but helpful
#
# ### Installation
#
# With conda:
# - `conda install -c conda-forge selenium`
#
# With pip:
# - `pip install -U selenium`
#
# #### ChromeDriver
#
# You will also need to install a web driver to use Selenium.  ChromeDriver is recommended but others are also available.
#
# 1. Check your browser's version _(Chrome > About Google Chrome)_
# ![Browser Version](images/browser_version.png)
# <br>
# 2. Navigate to the [ChromeDriver downloads page](https://sites.google.com/a/chromium.org/chromedriver/downloads).
# <br><br>
# 3. Download appropriately based on your browser's version and your OS.
# ![Download ChromeDriver zip file](images/chromedriver_options.png)
#
# 4. Unzip the driver.
# <br><br>
# 5. Move to Applications folder (or wherever your Chrome application is).

# %%
from bs4 import BeautifulSoup
import requests
import time, os

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %% [markdown]
# ## Example 1 - YouTube
#
# ### Dynamic Pages
#
# Some pages serve their content dynamically, which means they could look different each time they are loaded into the browser.  HTML that you see by inspecting elements in your browser might be missing from `requests` and `BeautifulSoup` because it is generated at access time.

# %%
query = "data science"
page_search = "http://carsalesbase.com/us-car-sales-analysis-2019-brands/"
youtube_query = youtube_search + query.replace(' ', '+')

# %%
page = requests.get(youtube_search).text
soup = BeautifulSoup(page, 'html5lib')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4286d921af06> in <module>
# ----> 1 page = requests.get(youtube_search).text
#       2 soup = BeautifulSoup(page, 'html5lib')
#
# NameError: name 'requests' is not defined

# %%
soup.find_all('div', id='contents')
# Out:
# []

# %% [markdown]
# Uh oh.  The video links should be under the contents div, but it's missing from our request.
#
# > **QUESTION**: Why do you think this happened?

# %% [markdown]
# One option is to first load the page with Selenium THEN parse the page's HTML with BeautifulSoup.
#
# First we launch the YouTube search page through our ChromeDrive.  A new browser should pop up.  **To continue using Selenium, keep this window open!**

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(youtube_query)

# %% [markdown]
# We can access the page's HTML through the driver:

# %%
driver.page_source[:1000]
# Out:
# '<html style="font-size: 10px;font-family: Roboto, Arial, sans-serif; " lang="en-US"><head><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2020-10-23" content="AhbmRDASY7NuOZD9cFMgQihZ+mQpCwa8WTGdTx82vSar9ddBQbziBfZXZg+ScofvEZDdHQNCEwz4yM7HjBS9RgkAAABneyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJXZWJDb21wb25lbnRzVjAiLCJleHBpcnkiOjE2MDM0ODY4NTYsImlzU3ViZG9tYWluIjp0cnVlfQ=="><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2020-10-27" content="Av2+1qfUp3MwEfAFcCccykS1qFmvLiCrMZ//pHQKnRZWG9dldVo8HYuJmGj2wZ7nDg+xE4RQMQ+Ku1zKM3PvYAIAAABmeyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IldlYkNvbXBvbmVudHNWMCIsImV4cGlyeSI6MTYwMzgzNjc3MiwiaXNTdWJkb21haW4iOnRydWV9"><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2021-01-08" content="AixUK+8UEShlt6+JX1wy9eg+XL+eV5PYSEDPH3C90JNVbIkE1Rg1FyVUfu2bZ/y6Pm1xbPLzuwHYHjv4uKPNnA4AAABqeyJvcmlnaW4iOiJodHRwczovL2dvb2dsZXByb2QuY29tOjQ0MyIsIm'

# %% [markdown]
# Now we parse this with `BeautifulSoup` and the video information appears!

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup.find('div', id='contents')
# Out:
# <div class="style-scope ytd-section-list-renderer" id="contents"><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack="">
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-promoted-sparkles-text-search-renderer class="style-scope ytd-item-section-renderer">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="root-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="main-container">
# <h3 class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="title" title="Domino Data Science Management - Start Your Free Trial Today">
#             Domino Data Science Management - Start Your Free Trial Today
#         </h3>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" ellipsis-truncate="" id="description" title="Data science platform that enables teams to develop &amp; deploy models that drive innovation. Get software that centralizes the people and tools used across the data science lifecycle. Model Risk Management. Model Management. Open Infrastructure. Cloud Data Science. AWS Data Science. Open Data Science. Highlights: We Are A Data Science Platform, Free Trial Available.">Data science platform that enables teams to develop &amp; deploy models that drive innovation. Get software that centralizes the people and tools used across the data science lifecycle. Model Risk Management. Model Management. Open Infrastructure. Cloud Data Science. AWS Data Science. Open Data Science. Highlights: We Are A Data Science Platform, Free Trial Available.</yt-formatted-string>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="format-container">
# <ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="ad-badge">
# <div class="badge badge-style-type-ad style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Ad</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer complex-string yt-simple-endpoint" ellipsis-truncate="" id="display-url" title="www.dominodatalab.com/Domino-Data/Get-Started"><span class="style-scope yt-formatted-string" style="color: rgb(6, 95, 212);">www.dominodatalab.com/Domino-Data/Get-Started</span></yt-formatted-string>
# </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="right-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="call-to-action"><ytd-button-renderer button-renderer="" class="style-scope ytd-promoted-sparkles-text-search-renderer style-suggestive" is-paper-button="" is-paper-button-with-icon="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://www.google.com/aclk?sa=l&amp;ai=DChcSEwjytIz475TnAhUN8MAKHU6NAgkYABAAGgJpbQ&amp;sig=AOD64_0zOca2nqTBl3NLg-u8qC6r93cbig&amp;adurl=&amp;ms=[CLICK_MS]&amp;nx=[NX]&amp;ny=[NY]&amp;nb=[NB]" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="VISIT SITE" class="style-scope ytd-button-renderer style-suggestive" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-suggestive" id="text">VISIT SITE</yt-formatted-string><yt-icon class="style-scope ytd-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 48 48"><g class="style-scope yt-icon" viewbox="0 0 48 48">
# <path class="style-scope yt-icon" d="M38 38H10V10h14V6H10c-2.21 0-4 1.79-4 4v28c0 2.21 1.79 4 4 4h28c2.21 0 4-1.79 4-4V24h-4v14zM28 6v4h7.17L15.51 29.66l2.83 2.83L38 12.83V20h4V6H28z"></path>
# </g></svg>
# </yt-icon></paper-button></a></ytd-button-renderer></div>
# </div>
# </div>
# </ytd-promoted-sparkles-text-search-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack="">
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-promoted-sparkles-text-search-renderer class="style-scope ytd-item-section-renderer">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="root-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="main-container">
# <h3 class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="title" title="Become A Data Scientist - 15 Week Data Science Bootcamp - 15 Week Course">
#             Become A Data Scientist - 15 Week Data Science Bootcamp - 15 Week Course
#         </h3>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" ellipsis-truncate="" id="description" title="Become A Well-Rounded Data Scientist In 15 Weeks And Embark On A New Career In Tech. Unlock Your Future With Data Science. Learn Online Or On-Campus And Change Your Career. Learn on your schedule. Scholarships available. Learn on campus or online. Python, SQL, ML, and more. Start learning today. Dedicated career support. Land a job in tech. Change your career.">Become A Well-Rounded Data Scientist In 15 Weeks And Embark On A New Career In Tech. Unlock Your Future With Data Science. Learn Online Or On-Campus And Change Your Career. Learn on your schedule. Scholarships available. Learn on campus or online. Python, SQL, ML, and more. Start learning today. Dedicated career support. Land a job in tech. Change your career.</yt-formatted-string>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="format-container">
# <ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer yt-simple-endpoint" id="ad-badge">
# <div class="badge badge-style-type-ad style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Ad</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <yt-formatted-string class="style-scope ytd-promoted-sparkles-text-search-renderer complex-string yt-simple-endpoint" ellipsis-truncate="" id="display-url" title="www.flatironschool.com/"><span class="style-scope yt-formatted-string" style="color: rgb(6, 95, 212);">www.flatironschool.com/</span></yt-formatted-string>
# </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="right-container">
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-promoted-sparkles-text-search-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# <div class="style-scope ytd-promoted-sparkles-text-search-renderer" id="call-to-action"><ytd-button-renderer button-renderer="" class="style-scope ytd-promoted-sparkles-text-search-renderer style-suggestive" is-paper-button="" is-paper-button-with-icon="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://www.google.com/aclk?sa=l&amp;ai=DChcSEwjytIz475TnAhUN8MAKHU6NAgkYABABGgJpbQ&amp;sig=AOD64_0yeSUcsZWztq63wAsJ-zT1AOWhOA&amp;adurl=&amp;ms=[CLICK_MS]&amp;nx=[NX]&amp;ny=[NY]&amp;nb=[NB]" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="VISIT SITE" class="style-scope ytd-button-renderer style-suggestive" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-suggestive" id="text">VISIT SITE</yt-formatted-string><yt-icon class="style-scope ytd-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 48 48"><g class="style-scope yt-icon" viewbox="0 0 48 48">
# <path class="style-scope yt-icon" d="M38 38H10V10h14V6H10c-2.21 0-4 1.79-4 4v28c0 2.21 1.79 4 4 4h28c2.21 0 4-1.79 4-4V24h-4v14zM28 6v4h7.17L15.51 29.66l2.83 2.83L38 12.83V20h4V6H28z"></path>
# </g></svg>
# </yt-icon></paper-button></a></ytd-button-renderer></div>
# </div>
# </div>
# </ytd-promoted-sparkles-text-search-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack="">
# <div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope paper-spinner-lite"><div class="circle-clipper left style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div><div class="circle-clipper right style-scope paper-spinner-lite"><div class="circle style-scope paper-spinner-lite"></div></div></div></div></paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=xC-c7E5PK0Y" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" loaded="" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/xC-c7E5PK0Y/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLAJ2GtYh4O81upkLzvUvdnaUWL8Ug" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="What REALLY is Data Science? Told by a Data Scientist by Joma Tech 1 year ago 11 minutes 998,862 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=xC-c7E5PK0Y" id="video-title" title="What REALLY is Data Science? Told by a Data Scientist">
# <yt-formatted-string aria-label="What REALLY is Data Science? Told by a Data Scientist by Joma Tech 1 year ago 11 minutes 998,862 views" class="style-scope ytd-video-renderer">What REALLY is Data Science? Told by a Data Scientist</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="Joma Tech"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/channel/UCV0qA-eDDICsRR9rPcnG7tw" spellcheck="false">Joma Tech</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name">
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg>
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">998K views</span>
# <span class="style-scope ytd-video-meta-block">1 year ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">► Want to land jobs at Facebook/Google/Microsoft/Amazon? Learn how to do that here:
# http://techinterviewpro.com/
#
# ► Resume ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges">
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">CC</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=ua-CiDNNj30" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" loaded="" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/ua-CiDNNj30/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLAelw14Ac-MNoN4dCoqf1SkEsyI8g" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Learn Data Science Tutorial - Full Course for Beginners by freeCodeCamp.org 7 months ago 5 hours 502,833 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=ua-CiDNNj30" id="video-title" title="Learn Data Science Tutorial - Full Course for Beginners">
# <yt-formatted-string aria-label="Learn Data Science Tutorial - Full Course for Beginners by freeCodeCamp.org 7 months ago 5 hours 502,833 views" class="style-scope ytd-video-renderer">Learn Data Science Tutorial - Full Course for Beginners</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="freeCodeCamp.org"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/channel/UC8butISFwT-Wl7EV0hUK0BQ" spellcheck="false">freeCodeCamp.org</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name">
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg>
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">502K views</span>
# <span class="style-scope ytd-video-meta-block">7 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">Learn <span class="bold style-scope yt-formatted-string">Data Science</span> is this full tutorial course for absolute beginners. <span class="bold style-scope yt-formatted-string">Data science</span> is considered the "sexiest job of the 21st ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges">
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">CC</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=X3paOmcrTjQ" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" loaded="" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/X3paOmcrTjQ/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLC9FKipYLpfVSJOwtdz2G9lSJWf9g" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn by Simplilearn 1 year ago 4 minutes, 38 seconds 739,381 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=X3paOmcrTjQ" id="video-title" title="Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn">
# <yt-formatted-string aria-label="Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn by Simplilearn 1 year ago 4 minutes, 38 seconds 739,381 views" class="style-scope ytd-video-renderer">Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="Simplilearn"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/user/Simplilearn" spellcheck="false">Simplilearn</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name">
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg>
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">739K views</span>
# <span class="style-scope ytd-video-meta-block">1 year ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">This <span class="bold style-scope yt-formatted-string">Data Science</span> tutorial video will give you an idea on the life of a <span class="bold style-scope yt-formatted-string">Data Scientist</span>, steps involved in <span class="bold style-scope yt-formatted-string">Data science</span> project, roles ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=DvGOq9WPsDg" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" loaded="" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/DvGOq9WPsDg/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLD9EixlMi69_zlnz7VquTIZ3QtVdg" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Data Scientist vs Data Analyst: What's the difference? ($120,000 vs $70,000 salary) by ENGINEERED TRUTH 3 months ago 4 minutes, 52 seconds 54,683 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=DvGOq9WPsDg" id="video-title" title="Data Scientist vs Data Analyst: What's the difference? ($120,000 vs $70,000 salary)">
# <yt-formatted-string aria-label="Data Scientist vs Data Analyst: What's the difference? ($120,000 vs $70,000 salary) by ENGINEERED TRUTH 3 months ago 4 minutes, 52 seconds 54,683 views" class="style-scope ytd-video-renderer">Data Scientist vs Data Analyst: What's the difference? ($120,000 vs $70,000 salary)</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="ENGINEERED TRUTH"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/user/EngineeredTruth" spellcheck="false">ENGINEERED TRUTH</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name">
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg>
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">54K views</span>
# <span class="style-scope ytd-video-meta-block">3 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">The average salary in <span class="bold style-scope yt-formatted-string">Data Science</span> is $120000, while the average salary in Data Analytics is $70000. So can a data analyst ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=iJUzouXg5kY" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" loaded="" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/iJUzouXg5kY/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLAOXil1loEAUbE1yK4kDWjjkLvRIw" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Demystifying Data Science | Mr.Asitang Mishra | TEDxOakLawn by TEDx Talks 5 months ago 15 minutes 18,770 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=iJUzouXg5kY" id="video-title" title="Demystifying Data Science | Mr.Asitang Mishra | TEDxOakLawn">
# <yt-formatted-string aria-label="Demystifying Data Science | Mr.Asitang Mishra | TEDxOakLawn by TEDx Talks 5 months ago 15 minutes 18,770 views" class="style-scope ytd-video-renderer">Demystifying Data Science | Mr.Asitang Mishra | TEDxOakLawn</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="TEDx Talks"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/user/TEDxTalks" spellcheck="false">TEDx Talks</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name">
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg>
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">18K views</span>
# <span class="style-scope ytd-video-meta-block">5 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">In this talk Mr.Asitang Mishra relates his experiences as a <span class="bold style-scope yt-formatted-string">Data Scientist</span> at the world famous NASA Jet Propulsion Laboratory ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=UXi8Ml2UoYk" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" loaded="" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/UXi8Ml2UoYk/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLDZfjUfVJDGZM_CIlotqabNn6DUCQ" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="What Do You Need to Become a Data Scientist in 2020? by 365 Data Science 10 months ago 9 minutes, 19 seconds 296,520 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=UXi8Ml2UoYk" id="video-title" title="What Do You Need to Become a Data Scientist in 2020?">
# <yt-formatted-string aria-label="What Do You Need to Become a Data Scientist in 2020? by 365 Data Science 10 months ago 9 minutes, 19 seconds 296,520 views" class="style-scope ytd-video-renderer">What Do You Need to Become a Data Scientist in 2020?</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg>
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="365 Data Science"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/channel/UCEBpSZhI1X8WaP-kY_2LLcg" spellcheck="false">365 Data Science</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">296K views</span>
# <span class="style-scope ytd-video-meta-block">10 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">So, you want to become a data scientist? Great! Check out the ultimate guide: http://bit.ly/2P1FEJl or watch this video to ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges">
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">CC</span>
# </div>
# ...
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">► Want to land jobs at Facebook/Google/Microsoft/Amazon? Learn how to do that here:
# http://techinterviewpro.com/
#
# ► Sign up ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=MpLHMKTolVw" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="The NBA Data Scientist by Bloomberg 8 months ago 8 minutes, 6 seconds 346,710 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=MpLHMKTolVw" id="video-title" title="The NBA Data Scientist">
# <yt-formatted-string aria-label="The NBA Data Scientist by Bloomberg 8 months ago 8 minutes, 6 seconds 346,710 views" class="style-scope ytd-video-renderer">The NBA Data Scientist</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="Bloomberg"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/user/Bloomberg" spellcheck="false">Bloomberg</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name">
# <div class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" clip-rule="evenodd" d="M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10 S17.52,2,12,2z M9.92,17.93l-4.95-4.95l2.05-2.05l2.9,2.9l7.35-7.35l2.05,2.05L9.92,17.93z" fill-rule="evenodd"></path>
# </g></svg>
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">346K views</span>
# <span class="style-scope ytd-video-meta-block">8 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">With her PhD in math, Ivana Seric had expected to wind up with a career in academia—but thanks to the growing use of statistical ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges">
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">4K</span>
# </div>
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">CC</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=dYZJxhYjBE8" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Real Talk with Instagram Data Scientist by Springboard 1 year ago 11 minutes 819,991 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=dYZJxhYjBE8" id="video-title" title="Real Talk with Instagram Data Scientist">
# <yt-formatted-string aria-label="Real Talk with Instagram Data Scientist by Springboard 1 year ago 11 minutes 819,991 views" class="style-scope ytd-video-renderer">Real Talk with Instagram Data Scientist</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="Springboard"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/channel/UCqd6TofKNjqagInm5Waeu7w" spellcheck="false">Springboard</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">819K views</span>
# <span class="style-scope ytd-video-meta-block">1 year ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">Talking <span class="bold style-scope yt-formatted-string">data science</span> with Mansha, a <span class="bold style-scope yt-formatted-string">data scientist</span> at Instagram. Previously at Blue Apron, Ernst &amp; Young and UPenn. Want to ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" lockup="">
# <div class="style-scope ytd-video-renderer" id="dismissable">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property="">
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=JbNegqgZKCw" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" style="background-color: transparent;"><img alt="" class="style-scope yt-img-shadow" id="img" width="246"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Real Talk with Google Data Scientist (with a PhD in Physics) by Springboard 10 months ago 12 minutes 353,086 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=JbNegqgZKCw" id="video-title" title="Real Talk with Google Data Scientist (with a PhD in Physics)">
# <yt-formatted-string aria-label="Real Talk with Google Data Scientist (with a PhD in Physics) by Springboard 10 months ago 12 minutes 353,086 views" class="style-scope ytd-video-renderer">Real Talk with Google Data Scientist (with a PhD in Physics)</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated">
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name">
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title="Springboard"><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/channel/UCqd6TofKNjqagInm5Waeu7w" spellcheck="false">Springboard</a></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" position="top" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">353K views</span>
# <span class="style-scope ytd-video-meta-block">10 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" id="description-text">Talking <span class="bold style-scope yt-formatted-string">data science</span> with Michael, a <span class="bold style-scope yt-formatted-string">data scientist</span> at Google. Previously at Mercedes. Want to learn <span class="bold style-scope yt-formatted-string">data science</span> with a job ...</yt-formatted-string>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"><yt-next-continuation class="style-scope ytd-item-section-renderer">
# <paper-spinner aria-hidden="true" class="style-scope yt-next-continuation" id="spinner"><!--css-build:shady--><div class="style-scope paper-spinner" id="spinnerContainer"><div class="spinner-layer layer-1 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-2 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-3 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div><div class="spinner-layer layer-4 style-scope paper-spinner"><div class="circle-clipper left style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div><div class="circle-clipper right style-scope paper-spinner"><div class="circle style-scope paper-spinner"></div></div></div></div></paper-spinner>
# <dom-if class="style-scope yt-next-continuation"><template is="dom-if"></template></dom-if>
# <dom-if class="style-scope yt-next-continuation"><template is="dom-if"></template></dom-if>
# </yt-next-continuation></div>
# </ytd-item-section-renderer></div>

# %%
contents_div = soup.find('div', id='contents')

for title in contents_div.find_all('a', id='video-title'):
    print(title.text.strip())
# Out:
# What REALLY is Data Science? Told by a Data Scientist
# Learn Data Science Tutorial - Full Course for Beginners
# Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn
# Data Scientist vs Data Analyst: What's the difference? ($120,000 vs $70,000 salary)
# Demystifying Data Science | Mr.Asitang Mishra | TEDxOakLawn
# What Do You Need to Become a Data Scientist in 2020?
# Is Data Science Really a Rising Career in 2020 ($100,000+ Salary)
# Data Science – Baba Brinkman Music Video
# Why I left my Data Science Job at FANG (Facebook Amazon Netflix Google)
# A Day in The Life of a Data Scientist 👨🏻‍💻| upGrad
# A Day In The Life Of A Data Scientist
# Python for Data Science | Data Science with Python | Python for Data Analysis | 11 Hours Full Course
# Can You Become a Data Scientist?
# Data Science: Reality vs Expectations ($100k+ Starting Salary 2018)
# Top 3 Programming Languages to Learn in 2019
# Data Science Full Course - Learn Data Science in 10 Hours | Data Science For Beginners | Edureka
# Solving real world data science tasks with Python Pandas!
# Data Scientist: Reality vs Expectations 2 ($110,000 Median Salary)
# Data Scientists vs Data Engineers: Which one is for you?
# The NBA Data Scientist
# Real Talk with Instagram Data Scientist
# Real Talk with Google Data Scientist (with a PhD in Physics)

# %% [markdown]
# > **QUESTION**: We only got about 20 video titles -- surely there are more videos about data science.  What do you think is happening?

# %% [markdown]
# ### Interacting with Pages
#
# We can also interact with pages using Selenium.  For example, we can
# - click
# - type in input cells
# - scroll
# - drag and drop, etc.
#
# If we want more data science video titles, we need to scroll down to the bottom of the screen for more videos to populate.

# %%
for i in range(5):
    #Scroll
    driver.execute_script(
        "window.scrollTo(0, document.documentElement.scrollHeight);" #Alternatively, document.body.scrollHeight
    )
    
    #Wait for page to load
    time.sleep(1)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
contents_div = soup.find('div', id='contents')

len(contents_div.find_all('a', id='video-title'))
# Out:
# 98

# %% [markdown]
# Awesome!  Now we have several more videos to analyze and we could continue scrolling if we wanted even more.
#
# What if we want to perform a new search for machine learning?

# %%
search_box = driver.find_element_by_xpath("//input[@id='search']")

#clear the current search
search_box.clear()

#input new search
search_box.send_keys("machine learning")

#hit enter
search_box.send_keys(Keys.RETURN)

# %% [markdown]
# And can we filter to short videos (< 4 minutes) only?

# %%
filter_button = driver.find_element_by_xpath(
    '//a[contains(@class, "ytd-toggle-button")]'
)
filter_button.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-15-18eaf896256b> in <module>
#       2     '//a[contains(@class, "ytd-toggle-button")]'
#       3 )
# ----> 4 filter_button.click()
#
# ~/opt/miniconda3/envs/metis/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/opt/miniconda3/envs/metis/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/miniconda3/envs/metis/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/miniconda3/envs/metis/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" tabindex="-1">...</a> is not clickable at point (133, 18). Other element would receive the click: <div id="logo-icon-container" class="yt-icon-container style-scope ytd-topbar-logo-renderer">...</div>
#   (Session info: chrome=79.0.3945.130)

# %%
short_link = driver.find_element_by_xpath(
    '//div[contains(@title, "Search for Short")]'
)
short_link.click()

# %% [markdown]
# Now we can either parse the page source with Beautiful Soup like before or pull text directly.
#
# For example, the title of the first short ML video (that isn't an ad!) can be found with:

# %%
first_title = driver.find_element_by_xpath("//a[@id='video-title']")
first_title.text

# %%
first_author = driver.find_element_by_xpath(
    "//ytd-video-renderer//ytd-channel-name//a"
)
first_author.text

# %% [markdown]
# #### Notes
#
# - Check [here](https://www.w3schools.com/xml/xpath_syntax.asp) for additonal help writing xpath selectors.
#
# - To select multiple elements, just switch to `driver.find_elements_by_xpath(...)`, which will return a list of matching elements.
#
# - You can also access elements by id, name, etc.  Check [the docs](https://selenium-python.readthedocs.io/locating-elements.html) for more options.

# %% [markdown]
# Finally, when you are finished with the driver, be sure to close it.

# %%
driver.close()

# %% [markdown]
# ## Example 2 - Open Table  _(Optional)_
#
# Let's try one more example: gathering information from Open Table about restaurants with available reservation slots.

# %%
driver = webdriver.Chrome(chromedriver)
driver.get('http://www.opentable.com/')
time.sleep(1)  #pause to be sure page has loaded

# %% [markdown]
# Inspecting this page, we see the **name** of the drop down for picking the number of people is `Select_1`. Let's set the reservation for 4 people:

# %%
people_dropdown = driver.find_element_by_name('Select_1')
people_dropdown.send_keys("4 people")
time.sleep(1)

# %% [markdown]
# Now select the reservation date: 3 days from now.

# %%
from datetime import datetime, timedelta

# %%
today = datetime.today()
today_truncated = datetime(today.year, today.month, today.day)
res_date = int((today_truncated + timedelta(days=3)).timestamp())
res_date  #Open Table uses unix time to label days

# %%
#Expand the calendar
date_picker = driver.find_element_by_name('datepicker')
date_picker.click()
time.sleep(1)

# %%
#Select the date three days from now
date_element = driver.find_element_by_xpath(f'//div[@data-pick={str(res_date)}000]')
date_element.click()
time.sleep(1)

# %% [markdown]
# Set our reservation time for 8 PM.

# %%
time_dropdown = driver.find_element_by_name('Select_0')
time_dropdown.send_keys("8:00 PM")
time.sleep(1)

# %% [markdown]
# And search!

# %%
search_button = driver.find_element_by_xpath('//input[@type="submit"]')
search_button.click()
time.sleep(1)

# %% [markdown]
# On this new page we find a long list of restaurants with available reservations for 4 people at roughly our desired day/time.  At this point we could grab the HTML (`driver.page_source`) and parse with BeautifulSoup.

# %%
soup = BeautifulSoup(driver.page_source)

# %%
for rest in soup.find_all('div', class_='rest-row-header')[:20]:
    print(rest.find('a').text)

# %% [markdown]
# Or we could click into an individual restaurant to learn more.

# %%
first_rest = driver.find_element_by_xpath('//div[@class="rest-row-header"]//a')
first_rest.click()

# %% [markdown]
# > **QUESTION**:  Why can't we click on a time to start booking a reservation? <br>
# `driver.find_element_by_xpath('//div[@data-auto="timeslot"]')`

# %%
#Switch windows!
driver.switch_to.window(driver.window_handles[1])

# %%
full_details_button = driver.find_element_by_xpath('//div[@data-auto="timeslot"]')
full_details_button.click()
time.sleep(1)

# %% [markdown]
# As usual when working with Selenium, make sure to close your browser.  Since we have two windows up, we use `driver.quit()` to close the entire browser session.

# %%
driver.quit()
